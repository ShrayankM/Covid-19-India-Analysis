# %% [markdown]
# #Main Covid-19 Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("covid_19_india.csv")

# %%
data.head()
# Out:
#    Sno      Date     Time  ... Cured Deaths Confirmed
# 0    1  30/01/20  6:00 PM  ...     0      0         1
# 1    2  31/01/20  6:00 PM  ...     0      0         1
# 2    3  01/02/20  6:00 PM  ...     0      0         2
# 3    4  02/02/20  6:00 PM  ...     0      0         3
# 4    5  03/02/20  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %% [markdown]
# #Cases Plots

# %%
states_india = data['State/UnionTerritory']
cases_india = data['Confirmed']
cured_india = data['Cured']

# %%
states_set = set(states_india)
states_set = sorted(states_set)
states_set.remove('Unassigned')
print(states_set)
# Out:
# ['Andaman and Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Mizoram', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu', 'Telengana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']

# %%
states_cases = dict()

# %%
for item in states_set:
    case_count = np.array(cases_india[states_india == item])
    states_cases[item] = case_count[-1]

# %%
print(states_cases)
# Out:
# {'Andaman and Nicobar Islands': 11, 'Andhra Pradesh': 381, 'Arunachal Pradesh': 1, 'Assam': 29, 'Bihar': 60, 'Chandigarh': 18, 'Chhattisgarh': 18, 'Delhi': 903, 'Goa': 7, 'Gujarat': 308, 'Haryana': 177, 'Himachal Pradesh': 28, 'Jammu and Kashmir': 207, 'Jharkhand': 17, 'Karnataka': 214, 'Kerala': 364, 'Ladakh': 15, 'Madhya Pradesh': 443, 'Maharashtra': 1574, 'Manipur': 2, 'Mizoram': 1, 'Odisha': 48, 'Puducherry': 7, 'Punjab': 132, 'Rajasthan': 553, 'Tamil Nadu': 911, 'Telengana': 504, 'Tripura': 2, 'Uttar Pradesh': 433, 'Uttarakhand': 35, 'West Bengal': 126}

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
states = states_cases.keys()
cases = states_cases.values()
ax.bar(states,cases,color='orange')
plt.xlabel('States', fontsize=20)
plt.ylabel('No. of Cases', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %%
states_case_copy = states_cases.copy()
sorted_cases = sorted(states_case_copy.items(),key = lambda item:item[1],reverse=True)

# %%
print(sorted_cases)
# Out:
# [('Maharashtra', 1574), ('Tamil Nadu', 911), ('Delhi', 903), ('Rajasthan', 553), ('Telengana', 504), ('Madhya Pradesh', 443), ('Uttar Pradesh', 433), ('Andhra Pradesh', 381), ('Kerala', 364), ('Gujarat', 308), ('Karnataka', 214), ('Jammu and Kashmir', 207), ('Haryana', 177), ('Punjab', 132), ('West Bengal', 126), ('Bihar', 60), ('Odisha', 48), ('Uttarakhand', 35), ('Assam', 29), ('Himachal Pradesh', 28), ('Chandigarh', 18), ('Chhattisgarh', 18), ('Jharkhand', 17), ('Ladakh', 15), ('Andaman and Nicobar Islands', 11), ('Goa', 7), ('Puducherry', 7), ('Manipur', 2), ('Tripura', 2), ('Arunachal Pradesh', 1), ('Mizoram', 1)]

# %%
states_list = list()
case_list   = list()
for item in sorted_cases:
    states_list.append(item[0])
    case_list.append(item[1])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
states = states_list
cases = case_list
ax.bar(states,cases,color='orange')
plt.xlabel('States', fontsize=20)
plt.ylabel('No. of Cases', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %% [markdown]
# #Cured Plots

# %%
states_cured = dict()

# %%
cured_count = []
for item in states_set:
    cured_count = np.array(cured_india[states_india == item])
    states_cured[item] = cured_count[-1]

# %%
print(states_cured)
# Out:
# {'Andaman and Nicobar Islands': 0, 'Andhra Pradesh': 11, 'Arunachal Pradesh': 0, 'Assam': 0, 'Bihar': 0, 'Chandigarh': 7, 'Chhattisgarh': 9, 'Delhi': 25, 'Goa': 1, 'Gujarat': 31, 'Haryana': 29, 'Himachal Pradesh': 6, 'Jammu and Kashmir': 6, 'Jharkhand': 0, 'Karnataka': 37, 'Kerala': 123, 'Ladakh': 10, 'Madhya Pradesh': 0, 'Maharashtra': 188, 'Manipur': 1, 'Mizoram': 0, 'Odisha': 2, 'Puducherry': 1, 'Punjab': 5, 'Rajasthan': 21, 'Tamil Nadu': 44, 'Telengana': 43, 'Tripura': 0, 'Uttar Pradesh': 32, 'Uttarakhand': 5, 'West Bengal': 16}

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
states = states_cured.keys()
cured = states_cured.values()
ax.bar(states,cured,color='green')
plt.xlabel('States', fontsize=20)
plt.ylabel('No. of Cured', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %%
states_cured_copy = states_cured.copy()
sorted_cured = sorted(states_cured_copy.items(),key = lambda item:item[1],reverse=True)

# %%
print(sorted_cured)
# Out:
# [('Maharashtra', 188), ('Kerala', 123), ('Tamil Nadu', 44), ('Telengana', 43), ('Karnataka', 37), ('Uttar Pradesh', 32), ('Gujarat', 31), ('Haryana', 29), ('Delhi', 25), ('Rajasthan', 21), ('West Bengal', 16), ('Andhra Pradesh', 11), ('Ladakh', 10), ('Chhattisgarh', 9), ('Chandigarh', 7), ('Himachal Pradesh', 6), ('Jammu and Kashmir', 6), ('Punjab', 5), ('Uttarakhand', 5), ('Odisha', 2), ('Goa', 1), ('Manipur', 1), ('Puducherry', 1), ('Andaman and Nicobar Islands', 0), ('Arunachal Pradesh', 0), ('Assam', 0), ('Bihar', 0), ('Jharkhand', 0), ('Madhya Pradesh', 0), ('Mizoram', 0), ('Tripura', 0)]

# %%
states_list = list()
cured_list   = list()
for item in sorted_cured:
    states_list.append(item[0])
    cured_list.append(item[1])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
states = states_list
cured = cured_list
ax.bar(states,cured,color='green')
plt.xlabel('States', fontsize=20)
plt.ylabel('No. of Cured', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %% [markdown]
# #Total Cases/Cured

# %%
N = len(states_set)
cases = states_cases.values()

ind = np.arange(N)  
width = 0.35       

fig = plt.figure()
ax = fig.add_subplot(111)
rects1 = ax.bar(ind, cases, width, color='royalblue')

cured = states_cured.values()

rects2 = ax.bar(ind+width, cured, width, color='seagreen')
ax.set_xlabel('States')
ax.set_ylabel('Cases/Cured')
ax.set_title('Cured and Cases')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels( states_cured.keys(),rotation = 90)

ax.legend( (rects1[0], rects2[0]), ('Cases', 'Cured') )
plt.gcf().set_size_inches([10,8])
plt.show()

# %% [markdown]
# #Rise of Cases in India

# %%
dates_india = data['Date']
cases_india = data['Confirmed']

# %%
dates_india_set = sorted(set(dates_india))

# %%
dates_cases = dict()

# %%
for date in dates_india_set:
    dates_cases[date] = sum(cases_india[dates_india == date])

# %%
from datetime import datetime
dates_list = list(dates_cases.keys())
dates_list.sort(key=lambda date: datetime.strptime(date,"%d/%m/%y"))

# %%
sorted_growth_dict = dict()
for date in dates_list:
    sorted_growth_dict[date] = dates_cases[date]

# %%
print(sorted_growth_dict)
# Out:
# {'30/01/20': 1, '31/01/20': 1, '01/02/20': 2, '02/02/20': 3, '03/02/20': 3, '04/02/20': 3, '05/02/20': 3, '06/02/20': 3, '07/02/20': 3, '08/02/20': 3, '09/02/20': 3, '10/02/20': 3, '11/02/20': 3, '12/02/20': 3, '13/02/20': 3, '14/02/20': 3, '15/02/20': 3, '16/02/20': 3, '17/02/20': 3, '18/02/20': 3, '19/02/20': 3, '20/02/20': 3, '21/02/20': 3, '22/02/20': 3, '23/02/20': 3, '24/02/20': 3, '25/02/20': 3, '26/02/20': 3, '27/02/20': 3, '28/02/20': 3, '29/02/20': 3, '01/03/20': 3, '02/03/20': 5, '03/03/20': 6, '04/03/20': 28, '05/03/20': 30, '06/03/20': 31, '07/03/20': 34, '08/03/20': 39, '09/03/20': 46, '10/03/20': 58, '11/03/20': 60, '12/03/20': 74, '13/03/20': 81, '14/03/20': 84, '15/03/20': 110, '16/03/20': 114, '17/03/20': 137, '18/03/20': 151, '19/03/20': 173, '20/03/20': 223, '21/03/20': 283, '22/03/20': 360, '23/03/20': 433, '24/03/20': 519, '25/03/20': 606, '26/03/20': 694, '27/03/20': 724, '28/03/20': 909, '29/03/20': 1024, '30/03/20': 1251, '31/03/20': 1397, '01/04/20': 1834, '02/04/20': 2069, '03/04/20': 2547, '04/04/20': 3072, '05/04/20': 3577, '06/04/20': 4281, '07/04/20': 4789, '08/04/20': 5274, '09/04/20': 5865, '10/04/20': 6761, '11/04/20': 7529}

# %%
cases_count_March_April = list(sorted_growth_dict.values())
cases_count_March_April = cases_count_March_April[31:]

# %%
print(cases_count_March_April)
# Out:
# [3, 5, 6, 28, 30, 31, 34, 39, 46, 58, 60, 74, 81, 84, 110, 114, 137, 151, 173, 223, 283, 360, 433, 519, 606, 694, 724, 909, 1024, 1251, 1397, 1834, 2069, 2547, 3072, 3577, 4281, 4789, 5274, 5865, 6761, 7529]

# %% [markdown]
# **Overall Rise of Cases in India**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
dates = np.arange(1,len(sorted_growth_dict.keys())-30,1)
cases = cases_count_March_April
ax.plot(dates,cases,color='green')
plt.xlabel('Dates:01/03/20 to 11/04/20', fontsize=20)
plt.ylabel('Cases', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %%
cases_March = cases_count_March_April[0:31]
cases_April = cases_count_March_April[31:]

# %%
dates_march = list(sorted_growth_dict.keys())[31:62]
dates_april = list(sorted_growth_dict.keys())[62:]

# %% [markdown]
# **Rise of Cases(Month March)**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
dates = dates_march
cases = cases_March 
ax.plot(dates,cases,color='green')
plt.xlabel('Dates', fontsize=20)
plt.ylabel('Cases', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %% [markdown]
# **Rise of Cases(Month April)**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
dates = dates_april
cases = cases_April
ax.plot(dates,cases,color='green')
plt.xlabel('Dates', fontsize=20)
plt.ylabel('Cases', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %% [markdown]
# #Rise of Deaths in India

# %%
deaths_india = data['Deaths']

# %%
dates_deaths = dict()

# %%
for date in dates_india_set:
    dates_deaths[date] = sum(deaths_india[dates_india == date])

# %%
sorted_death_dict = dict()
for date in dates_list:
    sorted_death_dict[date] = dates_deaths[date]

# %%
deaths_count_March_April = list(sorted_death_dict.values())[31:]

# %% [markdown]
# **Overall Rise in Deaths in India**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
dates = np.arange(1,len(sorted_death_dict.keys())-30,1)
deaths = deaths_count_March_April
ax.plot(dates,deaths,color='red')
plt.xlabel('Dates:01/03/20 to 11/04/20', fontsize=20)
plt.ylabel('Deaths:', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %%
deaths_March = deaths_count_March_April[0:31]
deaths_April = deaths_count_March_April[31:]

# %% [markdown]
# **Rise of Deaths(Month March)**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
dates = dates_march
deaths = deaths_March 
ax.plot(dates,deaths,color='red')
plt.xlabel('Dates', fontsize=20)
plt.ylabel('Deaths', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()

# %% [markdown]
# **Rise of Deaths(Month April)**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
dates = dates_april
deaths = deaths_April
ax.plot(dates,deaths,color='red')
plt.xlabel('Dates', fontsize=20)
plt.ylabel('Deaths', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches([10,8])
plt.show()
